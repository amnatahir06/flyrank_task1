# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/amnatahir06/flyrank_task1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I chose the Refresh / Content Opportunity Scoring lane because I want to identify which pages should be reviewed first for improvement or refresh. The dataset contains signals such as impressions, content age, freshness, position, CTR, and engagement, which can help us rank pages based on their potential opportunity or risk. The goal is not to automatically decide that a page should be changed, but to provide a useful ranked list that helps a human reviewer decide where to focus first.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# The decision is which pages should be reviewed first for a content refresh or improvement. A content or SEO team member would use the ranked list to decide where to spend limited review time. A wrong recommendation could waste time and resources on a page that does not need attention, while a genuinely useful page may be missed or reviewed too late. Therefore, the system will support human decision-making rather than automatically deciding which pages should be changed.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# !git clone https://github.com/amnatahir06/flyrank_task1.git
# %cd flyrank_task1

import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Total pages:", len(df))
print("Declining pages:", (df["trend_direction"].str.lower() == "down").sum())
print("Pages with impressions > 0:", (df["impressions_90d"] > 0).sum())
# Out:
# Cloning into 'flyrank_task1'...
# remote: Enumerating objects: 111, done.
# remote: Counting objects: 100% (111/111), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 111 (delta 28), reused 98 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (111/111), 1.82 MiB | 12.65 MiB/s, done.
# Resolving deltas: 100% (28/28), done.
# /content/flyrank_task1/flyrank_task1/flyrank_task1
# Total pages: 30000
# Declining pages: 16262
# Pages with impressions > 0: 30000

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project can identify pages that show signals of declining performance or content opportunity and rank them for human review. The results can provide **directional, evidence-based decision support** for deciding which pages should be reviewed first. I can say that certain signals are associated with higher review priority based on the data.
#
# However, this project cannot prove that refreshing a page will cause its performance to improve. It cannot prove causation, predict Google's algorithm, or guarantee that a page will recover after an action. The model is a prioritization tool to help a human team decide where to spend limited review time, not a replacement for human judgment.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ✔] Every section above is filled
# markdown thinking AND the code that backs it
# - [✔ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [✔ ] No client names, URLs, or private queries anywhere
# - [ ✔] My claims use careful words: observed, measured, directional, decision-support
# - [✔ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
